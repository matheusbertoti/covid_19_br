# %%
import pandas as pd
df = pd.read_csv('dados.csv', sep = ';')
print(df.dtypes)
# Out:
# C:\Users\mathe\AppData\Local\Temp\ipykernel_5940\3142320750.py:2: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dados.csv', sep = ';')
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# d:\Documentos\Projetos\GitHub\covid_19_br\campanha_vacinacao\analise_preliminar_campanha_vacinacao.ipynb Célula: 1 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Documentos/Projetos/GitHub/covid_19_br/campanha_vacinacao/analise_preliminar_campanha_vacinacao.ipynb#ch0000000?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/d%3A/Documentos/Projetos/GitHub/covid_19_br/campanha_vacinacao/analise_preliminar_campanha_vacinacao.ipynb#ch0000000?line=1'>2</a> df = pd.read_csv('dados.csv', sep = ';')
# ...
